# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from opensignalsreader import OpenSignalsReader
import os

# %%
## Import all files 
# Parameters
sourceDataFolder = '/Users/erwin/Documents/ProjectPsychophysiologyResources/source-data'
rawDataFolder = '/Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data/'
participants = ['sub-01', 'sub-02']
tasks = ['base', 'walk']
sessions = ['ground', 'high']

for pi in participants:
    for ti in tasks:
        for si in sessions:
            
            # assemble file name 
            filename = sourceDataFolder + '/' + pi + '_' + ti + '-' + si + '.txt'
    
            # skip the missing file 
            if filename ==  sourceDataFolder + '/sub-02_base-high.txt':
                print('skipping sub-02 base high file')
                continue
            
            # Convert all other files 
            acq = OpenSignalsReader(filename, show=True)
            
            # Access the processed ECG signal and print the first 5 elements
            ecg_signal = acq.signal('ECG') 
            print(ecg_signal[:5]) 
            
            # Access the processed EMG signal and print the first 5 elements
            emg_signal = acq.signal('EMG') 
            print(emg_signal[:5]) 
            
            ## Save data in a .csv format 
            output_filename_ecg = rawDataFolder + '/' + pi + '_' + ti + '-' + si + '_ecg.csv'
            output_filename_emg = rawDataFolder + '/' + pi + '_' + ti + '-' + si + '_emg.csv'
            
            # Save the NumPy array to a CSV file
            np.savetxt(output_filename_ecg, ecg_signal, delimiter=',', header='ECG')
            np.savetxt(output_filename_emg, emg_signal, delimiter=',', header='EMG')
            print(f"Wrote files {output_filename_ecg} and {output_filename_emg}")
# Out:
# [0.00292969 0.00585937 0.00585937 0.00878906 0.00585937]
# [ 0.          0.         -0.00638782 -0.00319391  0.00319391]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_base-ground_ecg.csv and /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_base-ground_emg.csv
# [-0.04101562 -0.04101562 -0.046875   -0.046875   -0.046875  ]
# [ 0.02235738  0.01277564 -0.00319391  0.01277564  0.00958173]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_base-high_ecg.csv and /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_base-high_emg.csv
# [0.01757812 0.01757812 0.00878906 0.00878906 0.0234375 ]
# [ 0.06068431 -0.06068431 -0.05110258 -0.01277564 -0.07984778]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_walk-ground_ecg.csv and /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_walk-ground_emg.csv
# [-0.0703125  -0.07910156 -0.08496094 -0.09082031 -0.09375   ]
# [0.00958173 0.00958173 0.01277564 0.01596956 0.00958173]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_walk-high_ecg.csv and /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-01_walk-high_emg.csv
# [0.00878906 0.00878906 0.01171875 0.01464844 0.01464844]
# [0.0287452  0.01916347 0.01596956 0.01277564 0.01916347]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-02_base-ground_ecg.csv and /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-02_base-ground_emg.csv
# skipping sub-02 base high file
# [ 0.01464844  0.00585937  0.         -0.00292969 -0.00585937]
# [0.00638782 0.00638782 0.01277564 0.00958173 0.01916347]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-02_walk-ground_ecg.csv and /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-02_walk-ground_emg.csv
# [0.04394531 0.03515625 0.02636719 0.02050781 0.01757812]
# [ 0.01596956  0.00958173  0.01277564  0.00319391 -0.01916347]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-02_walk-high_ecg.csv and /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//sub-02_walk-high_emg.csv

# %% [markdown]
# ## EDA example file
# Download this version : https://github.com/BITalinoWorld/revolution-sample-data
# which is compatible with the reader

# %%
# A simple way using OpenSingalsReader
edafilename = '/Users/erwin/Documents/ProjectPsychophysiologyResources/source-data/SampleEDA.txt'
edaacq = OpenSignalsReader(edafilename, show=True)

#for property, value in vars(edaacq).items():
#   print(property, ":", value)
    
# Access the processed ECG signal and print the first 5 elements
eda_signal = edaacq.signal('RAW') 
print(eda_signal[:5]) 

## Save data in a .csv format 
output_filename_eda = rawDataFolder + '/example_eda.csv'

# Save the NumPy array to a CSV file
np.savetxt(output_filename_eda, eda_signal, delimiter=',', header='EDA')
print(f"Wrote files {output_filename_eda}")
# Out:
# [102. 102. 102. 102. 102.]
# Wrote files /Users/erwin/Documents/ProjectPsychophysiologyResources/raw-data//example_eda.csv
